# %%
import os,json

# %%
label_description_path=r'C:\Users\91948\proj\label_descriptions.json'

# %%
# %%time
with open(label_description_path, 'r') as file:
    label_desc = json.load(file)
# Out:
# Wall time: 2 ms

# %%
for i in label_desc['categories']:
    print(i['name'])
#label_desc['categories'][0]["name"]
# Out:
# shirt, blouse
# top, t-shirt, sweatshirt
# sweater
# cardigan
# jacket
# vest
# pants
# shorts
# skirt
# coat
# dress
# jumpsuit
# cape
# glasses
# hat
# headband, head covering, hair accessory
# tie
# glove
# watch
# belt
# leg warmer
# tights, stockings
# sock
# shoe
# bag, wallet
# scarf
# umbrella
# hood
# collar
# lapel
# epaulette
# sleeve
# pocket
# neckline
# buckle
# zipper
# applique
# bead
# bow
# flower
# fringe
# ribbon
# rivet
# ruffle
# sequin
# tassel

# %%
# !pip install selenium

# %%
from bs4 import BeautifulSoup
import requests
URL = "https://www.flipkart.com/"
r = requests.get(URL)
#source=requests.get('https://open.spotify.com/search/sad/playlists').text
soup=BeautifulSoup(r.text,"lxml")
#print(r.content)
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
import requests, json
from bs4 import BeautifulSoup

headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

s = requests.Session()
res = s.get("https://www.myntra.com/shirt?p=1&plaEnabled=false", headers=headers, verify=False)

soup = BeautifulSoup(res.text,"html.parser")
print(soup)
# Out:
# C:\Users\91948\anaconda3\envs\myenv\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.myntra.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <!DOCTYPE html>
# ...

# %%
from requests_html import HTMLSession
import json
from bs4 import BeautifulSoup

headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

s = HTMLSession()
res = s.get("https://www.myntra.com/shirt?p=1&plaEnabled=false", headers=headers, verify=False)

soup = BeautifulSoup(res.text,"html.parser")
print(soup.html)
# Out:
# C:\Users\91948\anaconda3\envs\myenv\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.myntra.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><title>Shirt - Buy Shirt online in India</title><meta content="#fffff" name="theme-color"/><link href="https://constant.myntassets.com" rel="dns-prefetch preconnect"/><link href="https://assets.myntassets.com" rel="dns-prefetch preconnect"/><link href="https//www.googletagmanager.com" rel="dns-prefetch preconnect"/><link href="https//www.google-analytics.com" rel="dns-prefetch preconnect"/><link href="https//connect.facebook.net" rel="dns-prefetch preconnect"/><link href="https://www.facebook.com" rel="dns-prefetch preconnect"/><link href="https://touch.myntra.com" rel="dns-prefetch preconnect"/><link href="/manifest.json" rel="manifest"/><link href="https://www.myntra.com/opensearch.xml" rel="search" title="Myntra Fashion Search" type="application/opensearchdescription+xml"/>
# ...

# %%
# !pip install requests-html
# Out:
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13486 sha256=7ed2a6ba9de1dfeeb59ba73835032f6091da3cab3f6b1a309167ac819ab414f7
#   Stored in directory: c:\users\91948\appdata\local\pip\cache\wheels\ed\f7\62\50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24581 sha256=9050486b6673a6e22e0c6162e23db1ee6bbb15efb120a5aba4261887c83d50f3
#   Stored in directory: c:\users\91948\appdata\local\pip\cache\wheels\9c\aa\cc\f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
# Successfully built fake-useragent parse
# ...

# %%
val2=soup.find_all('script')
b=0
data
for i in val2[2]:
    print(b)
    data=json.loads(soup.find('script', type='application/ld+json').text)
    b+=1
# Out:
# 0
# <class 'bs4.element.Script'>

# %%
val=soup.find_all('script',class_='row-base')
print(val)
# Out:
# []

# %%
json.loads(soup.find_all('script', type='application/ld+json')[1].string)
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'ItemList',
#  'itemListElement': [{'@type': 'ListItem',
#    'position': 1,
#    'url': 'https://www.myntra.com/shirts/herenow/herenow-men-red--black-regular-fit-checked-casual-shirt/2414313/buy',
#    'name': 'HERE&NOW Men Red & Black Regular Fit Checked Casual Shirt'},
#   {'@type': 'ListItem',
#    'position': 2,
#    'url': 'https://www.myntra.com/shirts/highlander/highlander-men-navy--red-slim-fit-checked-casual-shirt/2129960/buy',
#    'name': 'HIGHLANDER Men Navy & Red Slim Fit Checked Casual Shirt'},
#   {'@type': 'ListItem',
#    'position': 3,
#    'url': 'https://www.myntra.com/shirts/campus-sutra/campus-sutra-men-navy-blue--grey-standard-fit-colourblocked-casual-shirt/10456354/buy',
#    'name': 'Campus Sutra Men Navy Blue & Grey Standard Fit Colourblocked Casual Shirt'},
#   {'@type': 'ListItem',
#    'position': 4,
# ...

# %%
res.html.render()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-9800845592ff> in <module>
# ----> 1 res.html.render()
#
# AttributeError: 'Response' object has no attribute 'html'

# %%
#import webbrowser
#for i in playlist_names[7:13]:
#    webbrowser.open('https://soundcloud.com'+i)

# %%
from selenium import webdriver
import urllib.request
import os
import json

# %%
driver = webdriver.Chrome(executable_path='C:/Users/91948/chromedriver.exe')
driver.get('https://www.myntra.com/')
driver.find_element_by_class_name('desktop-searchBar').send_keys(search_string)
driver.find_element_by_class_name('desktop-submit').click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4e03ab1145c5> in <module>
#       1 driver = webdriver.Chrome(executable_path='C:/Users/91948/chromedriver.exe')
#       2 driver.get('https://www.myntra.com/')
# ----> 3 driver.find_element_by_class_name('desktop-searchBar').send_keys(search_string)
#       4 driver.find_element_by_class_name('desktop-submit').click()
#
# NameError: name 'search_string' is not defined
